# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham3232/DS-YT/blob/main/pandas/6-PivotTables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

# %%
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    702     61   John  January      Q1
# 1  2023-01-02       B   West    908     24   Mary  January      Q1
# 2  2023-01-03       C  North    741     34    Bob  January      Q1
# 3  2023-01-04       D  South    702     78  Alice  January      Q1
# 4  2023-01-05       A   East    818     95   John  January      Q1
# 5  2023-01-06       B   West    182     74   Mary  January      Q1
# 6  2023-01-07       C  North    426     10    Bob  January      Q1
# 7  2023-01-08       D  South    264     63  Alice  January      Q1
# 8  2023-01-09       A   East    608     73   John  January      Q1
# 9  2023-01-10       B   West    448     77   Mary  January      Q1
# 10 2023-01-11       C  North    174     68    Bob  January      Q1
# 11 2023-01-12       D  South    308     58  Alice  January      Q1
# 12 2023-01-13       A   East    852     82   John  January      Q1
# 13 2023-01-14       B   West    683     19   Mary  January      Q1
# 14 2023-01-15       C  North    437     99    Bob  January      Q1
# 15 2023-01-16       D  South    399     78  Alice  January      Q1
# 16 2023-01-17       A   East    980     40   John  January      Q1
# 17 2023-01-18       B   West    220     28   Mary  January      Q1
# 18 2023-01-19       C  North    557     23    Bob  January      Q1
# 19 2023-01-20       D  South    617     53  Alice  January      Q1

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     818.0    NaN    NaN    NaN
# North      NaN    NaN  437.0    NaN
# South      NaN    NaN    NaN  399.0
# West       NaN  448.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')

# %%
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     792.0    NaN    NaN    NaN  70.2   NaN   NaN   NaN
# North      NaN    NaN  467.0    NaN   NaN   NaN  46.8   NaN
# South      NaN    NaN    NaN  458.0   NaN   NaN   NaN  66.0
# West       NaN  488.2    NaN    NaN   NaN  44.4   NaN   NaN

# %% [markdown]
# # Cross Tabs

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

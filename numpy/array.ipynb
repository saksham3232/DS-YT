# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham3232/DS-YT/blob/main/numpy/array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World

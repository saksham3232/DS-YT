# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham3232/DS-YT/blob/main/04-statistics/04-two-sample-T-test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as ttest_ind
import scipy.stats as stats

# %%
group_A = [85, 88, 90, 92, 87, 85, 89, 91, 86, 88]
group_B = [82, 84, 80, 83, 81, 79, 78, 85, 84, 83]

# %%
t_stats, p_value = stats.ttest_ind(group_A, group_B, equal_var=False)
print("t-statistic:", t_stats)
print("p-value:", p_value)
# Out:
# t-statistic: 5.829604009507161
# p-value: 1.610475598965881e-05

# %%
alpha = 0.05

# %%
if p_value < alpha:
  print("I will reject the null hypothesis")
else:
  print("I will accept the null hypothesis")
# Out:
# I will reject the null hypothesis

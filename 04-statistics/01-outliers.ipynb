# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham3232/DS-YT/blob/main/04-statistics/outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([2,3,4,6,7,8,9,12,13,16,17,23,25,27,34,37,201])
arr
# Out:
# array([  2,   3,   4,   6,   7,   8,   9,  12,  13,  16,  17,  23,  25,
#         27,  34,  37, 201])

# %%
Q1 = np.percentile(arr, 25)
Q1
# Out:
# np.float64(7.0)

# %%
Q3 = np.percentile(arr, 75)
Q3
# Out:
# np.float64(25.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(18.0)

# %%
UF = Q3 + 1.5*IQR
UF
# Out:
# np.float64(52.0)

# %%
LF = Q1 - 1.5*IQR
LF
# Out:
# np.float64(-20.0)

# %%
l = []
for i in arr:
  if i >= LF and i <=UF:
    l.append(i)
arr2 = np.array(l)

# %%
print(arr)
print(arr2)
# Out:
# [  2   3   4   6   7   8   9  12  13  16  17  23  25  27  34  37 201]
# [ 2  3  4  6  7  8  9 12 13 16 17 23 25 27 34 37]

# %%
import seaborn as sns
sns.boxplot(arr)
# Out:
# <Axes: >

# %%
sns.boxplot(arr2)
# Out:
# <Axes: >
